# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
path="D:\Ai\Data Analyst Internn\ABDELGHAFOR’S VIRTUAL INTERNSHIPS Data Analysis\session 1\Task1\movie.csv"
df_movie=pd.read_csv(path)

# %%
pd.set_option("display.max_columns",len(df_movie.columns))

# %% [markdown]
# # EDA

# %%
df_movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df_movie.sample(10)
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 4039  Color            Deon Taylor                    63.0      88.0
# 3879  Color  Aleksandr Veledinskiy                     8.0     120.0
# 2655  Color            Woody Allen                    42.0     124.0
# 316   Color             Ron Howard                   289.0     122.0
# 2168  Color            Neil LaBute                   165.0     110.0
# 343   Color             John Moore                   412.0     101.0
# 4648  Color           Marc Forster                    24.0      87.0
# 1388  Color           Roland Joffé                    77.0     102.0
# 1186  Color              James Wan                   300.0     134.0
# 2438  Color             Lance Hool                    10.0     121.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 4039                     26.0                   236.0       Betsy Russell
# ...

# %%
df_movie.shape
# Out:
# (4916, 28)

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
df_movie.describe().round(1)
# Out:
#        num_critic_for_reviews  duration  director_facebook_likes  \
# count                  4867.0    4901.0                   4814.0
# mean                    138.0     107.1                    691.0
# std                     120.2      25.3                   2833.0
# min                       1.0       7.0                      0.0
# 25%                      49.0      93.0                      7.0
# 50%                     108.0     103.0                     48.0
# 75%                     191.0     118.0                    189.8
# max                     813.0     511.0                  23000.0
#
#        actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# count                  4893.0                  4909.0       4054.0
# mean                    631.3                  6494.5   47644514.5
# std                    1625.9                 15107.0   67372553.8
# min                       0.0                     0.0        162.0
# ...

# %%
df_movie["title_year"]=pd.to_datetime(df_movie["title_year"],format="%Y")

# %%
df_movie["title_year"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4916 entries, 0 to 4915
# Series name: title_year
# Non-Null Count  Dtype
# --------------  -----
# 4810 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 38.5 KB

# %% [markdown]
# # Clean Data

# %%
df_movie.isna().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %%
### Normalize The number of NAN
((df_movie.isna().sum() /4916 ) *100).round(2)
# Out:
# color                         0.39
# director_name                 2.07
# num_critic_for_reviews        1.00
# duration                      0.31
# director_facebook_likes       2.07
# actor_3_facebook_likes        0.47
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.47
# facenumber_in_poster          0.26
# plot_keywords                 3.09
# movie_imdb_link               0.00
# num_user_for_reviews          0.43
# language                      0.28
# country                       0.10
# content_rating                6.10
# budget                        9.85
# title_year                    2.16
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.63
# ...

# %%
for col in df_movie.select_dtypes("object").columns:
    print(f"({col}) number of unique values is {df_movie[col].nunique()}\n and the values is \n {df_movie[col].unique()} \n \n \n  -------------------------")
# Out:
# (color) number of unique values is 2
#  and the values is
#  ['Color' nan 'Black and White']
#
#
#   -------------------------
# (director_name) number of unique values is 2397
#  and the values is
#  ['James Cameron' 'Gore Verbinski' 'Sam Mendes' ... 'Scott Smith'
#  'Benjamin Roberds' 'Daniel Hsia']
#
#
#   -------------------------
# (actor_2_name) number of unique values is 3030
#  and the values is
#  ['Joel David Moore' 'Orlando Bloom' 'Rory Kinnear' ... 'Valorie Curry'
#  'Maxwell Moody' 'Brian Herzlinger']
#
#
#   -------------------------
# (genres) number of unique values is 914
#  and the values is
#  ['Action|Adventure|Fantasy|Sci-Fi' 'Action|Adventure|Fantasy'
#  'Action|Adventure|Thriller' 'Action|Thriller' 'Documentary'
#  'Action|Adventure|Sci-Fi' 'Action|Adventure|Romance'
#  'Adventure|Animation|Comedy|Family|Fantasy|Musical|Romance'
#  'Adventure|Family|Fantasy|Mystery' 'Action|Adventure'
#  'Action|Adventure|Western' 'Action|Adventure|Family|Fantasy'
# ...

# %%
df_movie["gross"]
# Out:
# 0       760505847.0
# 1       309404152.0
# 2       200074175.0
# 3       448130642.0
# 4               NaN
#            ...
# 4911            NaN
# 4912            NaN
# 4913            NaN
# 4914        10443.0
# 4915        85222.0
# Name: gross, Length: 4916, dtype: float64

# %%
df_movie["gross"].fillna(df_movie["gross"].median(),inplace=True)

# %%
df_movie["gross"].describe().round(1)
# Out:
# count         4916.0
# mean      43681602.4
# std       61780807.0
# min            162.0
# 25%        8066303.2
# 50%       25043962.0
# 75%       50875351.2
# max      760505847.0
# Name: gross, dtype: float64

# %%
df_movie["budget"].fillna(df_movie["budget"].median(),inplace=True)

# %%
df_movie["budget"].describe().round(1)
# Out:
# count    4.916000e+03
# mean     3.490355e+07
# std      9.530908e+07
# min      2.180000e+02
# 25%      7.000000e+06
# 50%      1.985000e+07
# 75%      4.000000e+07
# max      4.200000e+09
# Name: budget, dtype: float64

# %%
df_movie.dropna(inplace=True)

# %%
((df_movie.isna().sum() /4916 ) *100).round(2)
# Out:
# color                        0.0
# director_name                0.0
# num_critic_for_reviews       0.0
# duration                     0.0
# director_facebook_likes      0.0
# actor_3_facebook_likes       0.0
# actor_2_name                 0.0
# actor_1_facebook_likes       0.0
# gross                        0.0
# genres                       0.0
# actor_1_name                 0.0
# movie_title                  0.0
# num_voted_users              0.0
# cast_total_facebook_likes    0.0
# actor_3_name                 0.0
# facenumber_in_poster         0.0
# plot_keywords                0.0
# movie_imdb_link              0.0
# num_user_for_reviews         0.0
# language                     0.0
# country                      0.0
# content_rating               0.0
# budget                       0.0
# title_year                   0.0
# actor_2_facebook_likes       0.0
# imdb_score                   0.0
# aspect_ratio                 0.0
# movie_facebook_likes         0.0
# dtype: float64

# %%
df_movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 4899  Color    Olivier Assayas                    81.0     110.0
# 4900  Color       Jafar Panahi                    64.0      90.0
# 4906  Color      Shane Carruth                   143.0      77.0
# 4908  Color   Robert Rodriguez                    56.0      81.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %% [markdown]
# # Dealing With Outliers

# %%
# Show trends in numerical columns
df_movie.plot(subplots=True,figsize=(16,35))
plt.show()

# %%
per25th=df_movie["budget"].quantile(0.25)
print(per25th)
per75th=df_movie["budget"].quantile(0.75)
print(per75th)
# Out:
# 9000000.0
# 45000000.0

# %%
IQR=per75th-per25th
IQR
# Out:
# 36000000.0

# %%
upper= per75th+(IQR*1.5)
lower = per25th - ( IQR * 1.5)

print(upper,lower)
# Out:
# 99000000.0 -45000000.0

# %%
df_movie[(df_movie["budget"] > upper) | (df_movie["budget"] < lower)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 335 entries, 0 to 4440
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      335 non-null    object
#  1   director_name              335 non-null    object
#  2   num_critic_for_reviews     335 non-null    float64
#  3   duration                   335 non-null    float64
#  4   director_facebook_likes    335 non-null    float64
#  5   actor_3_facebook_likes     335 non-null    float64
#  6   actor_2_name               335 non-null    object
#  7   actor_1_facebook_likes     335 non-null    float64
#  8   gross                      335 non-null    float64
#  9   genres                     335 non-null    object
#  10  actor_1_name               335 non-null    object
#  11  movie_title                335 non-null    object
#  12  num_voted_users            335 non-null    int64
# ...

# %%
df_movie = df_movie[~((df_movie["budget"] > upper) | (df_movie["budget"] < lower))]

# %%
per25th=df_movie["gross"].quantile(0.25)
print(per25th)
per75th=df_movie["gross"].quantile(0.75)
print(per75th)
# Out:
# 7022940.0
# 48291624.0

# %%
IQR=per75th-per25th
IQR
# Out:
# 41268684.0

# %%
upper= per75th+(IQR*1.5)
lower = per25th - ( IQR * 1.5)

print(upper,lower)
# Out:
# 110194650.0 -54880086.0

# %%
df_movie = df_movie[~((df_movie["gross"] > upper) | (df_movie["gross"] < lower))]

# %%
df_movie.shape
# Out:
# (3680, 28)

# %% [markdown]
# # Visualization

# %%
df_movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
import matplotlib.ticker as ticker

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x=df_movie["title_year"],y=df_movie["budget"])
plt.title("Movies budget over the years")
plt.xlabel("Years")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.lineplot(x=df_movie["title_year"],y=df_movie["gross"])
plt.title("Movies gross over the years")
plt.xlabel("Years")
plt.ylabel("Gross")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x*1e-6:.0f}M'))
plt.show()

# %%
sort_movie_title=df_movie.sort_values(by="budget",ascending=False)

# %%
plt.figure(figsize=(20,6))
sns.barplot(x=sort_movie_title["movie_title"][:20],y=sort_movie_title["budget"][:20])
plt.title("Highest gross")
plt.xlabel("Movies")
plt.ylabel("Gross")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x*1e-6:.0f}M'))

plt.xticks(rotation=90)
plt.show()

# %%
Rating=df_movie.groupby("content_rating")["gross"].mean().round(1).sort_values(ascending=False)

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=Rating.index,y=Rating.values)
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.xlabel("Content Rating")
plt.ylabel("Gross")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x=df_movie["imdb_score"],y=df_movie["gross"])
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(x=df_movie["gross"],y=df_movie["movie_facebook_likes"])
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(y=df_movie["facenumber_in_poster"],x=df_movie["gross"])
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.lmplot(data=df_movie,x="duration",y="gross",line_kws={'color': 'red'},scatter_kws={'s': 5})
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.lmplot(data=df_movie,x="duration",y="budget",line_kws={'color': 'red'},scatter_kws={'s': 5})
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.lmplot(data=df_movie,x="budget",y="gross",line_kws={'color': 'red'},scatter_kws={'s': 5})
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.violinplot(data=df_movie,x="color",y="budget")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.violinplot(data=df_movie,x="color",y="gross")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x,_:f'{x*1e-6:.0f}M'))
plt.show()
